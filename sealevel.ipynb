# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
file_path = "/Users/Bartlomiejszafran/Desktop/Sealevel/epa-sea-level.csv"
data = pd.read_csv( "/Users/Bartlomiejszafran/Desktop/Sealevel/epa-sea-level.csv")
y = data["CSIRO Adjusted Sea Level"]
x = data["Year"]

# %%
data.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax = plt.scatter(x, y)

# %%
slope, intercept, r_value, p_value , stderr = linregress(x, y)
x_pred = pd.Series([i for i in range (1880, 2051)])
y_pred = slope*x_pred + intercept
plt.plot(x_pred, y_pred, 'r')
plt.show()

# %%
df_forecast = data.loc[data['Year'] >= 2000]
x_forecast = df_forecast['Year']
y_forecast = df_forecast ['CSIRO Adjusted Sea Level']
df_forecast
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 120  2000                  7.062992           6.791339           7.334646
# 121  2001                  7.287402           7.019685           7.555118
# 122  2002                  7.381890           7.110236           7.653543
# 123  2003                  7.759843           7.484252           8.035433
# 124  2004                  7.740157           7.464567           8.015748
# 125  2005                  7.744094           7.472441           8.015748
# 126  2006                  7.917323           7.645669           8.188976
# 127  2007                  7.996063           7.712598           8.279528
# 128  2008                  8.350394           8.078740           8.622047
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# ...

# %%
slope, intercept, r_value, p_value , stderr = linregress(x_forecast, y_forecast)
x_pred2 = pd.Series([i for i in range (2000, 2051)])
y_pred2 = slope*x_pred2 + intercept
plt.plot(x_pred2, y_pred2, 'g')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax = plt.scatter(x, y)
plt.plot(x_pred, y_pred, 'r')
plt.plot(x_pred2, y_pred2, 'g')
plt.title ('Sea Level predictor')
plt.xlabel ('Year')
plt.ylabel ('Sea level')
plt.show()
